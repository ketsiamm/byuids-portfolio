# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('https://raw.githubusercontent.com/byui-cse/cse450-course/master/data/bank.csv')

# %%
campaign.dtypes
# Out:
# age                 int64
# job                object
# marital            object
# education          object
# default            object
# housing            object
# loan               object
# contact            object
# month              object
# day_of_week        object
# campaign            int64
# pdays               int64
# previous            int64
# poutcome           object
# emp.var.rate      float64
# cons.price.idx    float64
# cons.conf.idx     float64
# euribor3m         float64
# nr.employed       float64
# y                  object
# dtype: object

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

campaign = pd.read_csv('https://raw.githubusercontent.com/byui-cse/cse450-course/master/data/bank.csv')


correlation_matrix = campaign.corr()

# Plotting the correlation matrix as a heatmap
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix of Bank Campaign Data')
plt.show()

# %%
sns.pairplot(campaign)

# %%
plt.figure(figsize=(10, 5))
sns.barplot(x="job", y="y", data=df, order=df["job"].value_counts().index, palette="coolwarm")
plt.xticks(rotation=45)
plt.title("Subscription Rate by Job")
plt.ylabel("Proportion of Subscription (y = 1)")
plt.xlabel("Job")
plt.show()
# Out:
# <ipython-input-9-d36f06ed45e0>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="job", y="y", data=df, order=df["job"].value_counts().index, palette="coolwarm")

# %% [markdown]
# Categorical data comparison

# %%
plt.figure(figsize=(8, 5))
sns.barplot(x="marital", y="y", data=df, order=df["marital"].value_counts().index, palette="coolwarm")
plt.title("Subscription Rate by Marital Status")
plt.ylabel("Proportion of Subscription (y = 1)")
plt.xlabel("Marital Status")
plt.show()
# Out:
# <ipython-input-10-bbc78638b314>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="marital", y="y", data=df, order=df["marital"].value_counts().index, palette="coolwarm")

# %%
plt.figure(figsize=(10, 5))
sns.barplot(x="education", y="y", data=df, order=df["education"].value_counts().index, palette="coolwarm")
plt.xticks(rotation=45)
plt.title("Subscription Rate by Education")
plt.ylabel("Proportion of Subscription (y = 1)")
plt.xlabel("Education Level")
plt.show()
# Out:
# <ipython-input-11-3e39b6bef9a1>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="education", y="y", data=df, order=df["education"].value_counts().index, palette="coolwarm")

# %%
plt.figure(figsize=(6, 5))
sns.barplot(x="default", y="y", data=df, order=df["default"].value_counts().index, palette="coolwarm")
plt.title("Subscription Rate by Credit Default")
plt.ylabel("Proportion of Subscription (y = 1)")
plt.xlabel("Credit Default")
plt.show()
# Out:
# <ipython-input-12-3d1139fbde1f>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="default", y="y", data=df, order=df["default"].value_counts().index, palette="coolwarm")

# %%
plt.figure(figsize=(6, 5))
sns.barplot(x="housing", y="y", data=df, order=df["housing"].value_counts().index, palette="coolwarm")
plt.title("Subscription Rate by Housing Loan")
plt.ylabel("Proportion of Subscription (y = 1)")
plt.xlabel("Housing Loan")
plt.show()
# Out:
# <ipython-input-13-108e6f084c9a>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="housing", y="y", data=df, order=df["housing"].value_counts().index, palette="coolwarm")

# %%
plt.figure(figsize=(6, 5))
sns.barplot(x="loan", y="y", data=df, order=df["loan"].value_counts().index, palette="coolwarm")
plt.title("Subscription Rate by Personal Loan")
plt.ylabel("Proportion of Subscription (y = 1)")
plt.xlabel("Personal Loan")
plt.show()
# Out:
# <ipython-input-14-d29c0ae17513>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="loan", y="y", data=df, order=df["loan"].value_counts().index, palette="coolwarm")

# %%
plt.figure(figsize=(6, 5))
sns.barplot(x="contact", y="y", data=df, order=df["contact"].value_counts().index, palette="coolwarm")
plt.title("Subscription Rate by Contact Type")
plt.ylabel("Proportion of Subscription (y = 1)")
plt.xlabel("Contact Type")
plt.show()
# Out:
# <ipython-input-15-8521ee34df0f>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="contact", y="y", data=df, order=df["contact"].value_counts().index, palette="coolwarm")

# %%
plt.figure(figsize=(10, 5))
sns.barplot(x="month", y="y", data=df, order=df["month"].value_counts().index, palette="coolwarm")
plt.title("Subscription Rate by Last Contact Month")
plt.ylabel("Proportion of Subscription (y = 1)")
plt.xlabel("Month")
plt.show()
# Out:
# <ipython-input-16-35d70cbcda87>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="month", y="y", data=df, order=df["month"].value_counts().index, palette="coolwarm")

# %%
plt.figure(figsize=(8, 5))
sns.barplot(x="day_of_week", y="y", data=df, order=df["day_of_week"].value_counts().index, palette="coolwarm")
plt.title("Subscription Rate by Day of the Week")
plt.ylabel("Proportion of Subscription (y = 1)")
plt.xlabel("Day of the Week")
plt.show()
# Out:
# <ipython-input-19-2b566c2200fb>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="day_of_week", y="y", data=df, order=df["day_of_week"].value_counts().index, palette="coolwarm")

# %%
plt.figure(figsize=(6, 5))
sns.barplot(x="poutcome", y="y", data=df, order=df["poutcome"].value_counts().index, palette="coolwarm")
plt.title("Subscription Rate by Previous Campaign Outcome")
plt.ylabel("Proportion of Subscription (y = 1)")
plt.xlabel("Previous Campaign Outcome")
plt.show()
# Out:
# <ipython-input-20-4b38ff745bc8>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="poutcome", y="y", data=df, order=df["poutcome"].value_counts().index, palette="coolwarm")

# %% [markdown]
# numerical data comparison

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


# List of numerical variables
num_vars = ["age", "campaign", "pdays", "previous", "emp.var.rate",
            "cons.price.idx", "cons.conf.idx", "euribor3m", "nr.employed"]

# Set up the figure with subplots (3 rows, 3 columns)
fig, axes = plt.subplots(3, 3, figsize=(15, 12))
fig.suptitle("Comparison of Numerical Variables with Subscription Outcome (y)")

# Loop through variables and create boxplots
for i, var in enumerate(num_vars):
    row, col = divmod(i, 3)  # Determine subplot position
    sns.boxplot(data=df, x="y", y=var, ax=axes[row, col], palette="Set2")
    axes[row, col].set_title(f"Distribution of {var} by Subscription Outcome")

# Adjust layout for readability
plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()
# Out:
# <ipython-input-22-05b8043a5c2d>:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x="y", y=var, ax=axes[row, col], palette="Set2")
# <ipython-input-22-05b8043a5c2d>:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x="y", y=var, ax=axes[row, col], palette="Set2")
# <ipython-input-22-05b8043a5c2d>:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x="y", y=var, ax=axes[row, col], palette="Set2")
# <ipython-input-22-05b8043a5c2d>:17: FutureWarning:
#
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt



# Define numerical columns
numerical_cols = ["age", "campaign", "pdays", "previous", "emp.var.rate",
                  "cons.price.idx", "cons.conf.idx", "euribor3m", "nr.employed"]

# Set up the figure with subplots
fig, axes = plt.subplots(nrows=3, ncols=3, figsize=(15, 12))
fig.suptitle("Violin Plots: Numerical Variables vs. Subscription Outcome (y)", fontsize=16)

# Flatten axes for iteration
axes = axes.flatten()

# Create a violin plot for each numerical variable
for i, col in enumerate(numerical_cols):
    sns.violinplot(data=df, x="y", y=col, ax=axes[i], palette="Set2", inner="quartile")
    axes[i].set_title(f"{col} vs. y")
    axes[i].set_xlabel("Subscribed (y)")
    axes[i].set_ylabel(col)

# Adjust layout for better spacing
plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()
# Out:
# <ipython-input-24-5e31f360bc36>:20: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df, x="y", y=col, ax=axes[i], palette="Set2", inner="quartile")
# <ipython-input-24-5e31f360bc36>:20: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df, x="y", y=col, ax=axes[i], palette="Set2", inner="quartile")
# <ipython-input-24-5e31f360bc36>:20: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df, x="y", y=col, ax=axes[i], palette="Set2", inner="quartile")
# <ipython-input-24-5e31f360bc36>:20: FutureWarning:
#
# ...
